# %%
# ----------------------------------------------------------------------------
# Visualize
# ----------------------------------------------------------------------------
from dependencies import *
from init import *
from vector_field import *

# %%
# z stuff
force_fieldSlice2DFig, force_fieldSlice2DAx = plt.subplots()

# forceX = force_field[:, :, 100, 0]
# forceZ = force_field[:, :, 100, 2]
forceX = force_field[20:30, 20:30, 20, 0]
forceZ = force_field[20:30, 20:30, 20, 2]
# forceX = force_field[15:35, 15:35, 20, 0]
# forceZ = force_field[15:35, 15:35, 20, 2]
# forceX = force_field[10:40, 10:40, 20, 0]
# forceZ = force_field[10:40, 10:40, 20, 2]

selected_points = forceX.shape[0]

x2d, y2d = np.meshgrid(np.linspace(-r_inner, r_inner, selected_points), \
                       np.linspace(-r_inner, r_inner, selected_points))


force_fieldSlice2DAx.quiver(x2d, y2d, forceX, forceZ)

force_fieldSlice2DAx.axis('equal')

force_fieldSlice2DAx.set_title(\
    '2D Slice of Force Field in Circular Halbach Array Magnetic Field')
force_fieldSlice2DAx.set_ylabel('z (mm)')
force_fieldSlice2DAx.set_xlabel('x (mm)')

plt.show()

# %%
# Plot force field
force_fieldSlice2DFig, force_fieldSlice2DAx = plt.subplots()
# force_fieldSlice2DAx.plot(x, y, 'k')

loc = 65
# forceX = force_field[:, :, loc, 0]
# forceY = force_field[:, :, loc, 1]
# forceX = force_field[20:30, 20:30, loc, 0]
# forceY = force_field[20:30, 20:30, loc, 1]
# forceX = force_field[15:35, 15:35, loc, 0]
# forceY = force_field[15:35, 15:35, loc, 1]
forceX = force_field[10:40, 10:40, loc, 0]
forceY = force_field[10:40, 10:40, loc, 1]

selected_points = forceX.shape[0]

x2d, y2d = np.meshgrid(np.linspace(-r_inner, r_inner, selected_points), \
                       np.linspace(-r_inner, r_inner, selected_points))


force_fieldSlice2DAx.quiver(x2d, y2d, forceX, forceY)

force_fieldSlice2DAx.axis('equal')

force_fieldSlice2DAx.set_title(\
    '2D Slice of Force Field in Circular Halbach Array Magnetic Field')
force_fieldSlice2DAx.set_ylabel('y (mm)')
force_fieldSlice2DAx.set_xlabel('x (mm)')

plt.show()
